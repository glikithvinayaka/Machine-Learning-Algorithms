# %%
import pandas as pd 
import numpy as np
import seaborn as sns
sns.set()

# %%
# Load dataset middle_tn_schools.csv
df = pd.read_csv('middle_tn_schools.csv')

# %%
# Check Shape
# Out:
# (347, 15)

# %%
# view first 5 rows as sample
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
# Correlation matrix
# Out:
#                      school_rating  size  reduced_lunch  state_percentile_16  \
# school_rating                 1.00  0.18          -0.82                 0.99
# size                          0.18  1.00          -0.28                 0.17
# reduced_lunch                -0.82 -0.28           1.00                -0.82
# state_percentile_16           0.99  0.17          -0.82                 1.00
# state_percentile_15           0.94  0.16          -0.83                 0.95
# stu_teach_ratio               0.20  0.14          -0.20                 0.19
# avg_score_15                  0.94  0.16          -0.84                 0.95
# avg_score_16                  0.98  0.14          -0.82                 0.99
# full_time_teachers            0.12  0.97          -0.21                 0.12
# percent_black                -0.59 -0.15           0.56                -0.57
# percent_white                 0.64  0.10          -0.67                 0.63
# ...

# %%
# heatmap of correlation matrix

# %%
# correlation between reduced_lunch & school_rating
# Out:
#                reduced_lunch  school_rating
# reduced_lunch           1.00          -0.82
# school_rating          -0.82           1.00

# %% [markdown]
# # END
